# %%
# CÉLULA 1: Importar Bibliotecas e Preparar Dados

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Configurações
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Carregar dataset
df = pd.read_csv('../dados/ai_job_market_dataset.csv')

print("✅ Bibliotecas importadas!")
print(f"✅ Dataset carregado: {df.shape[0]} linhas, {df.shape[1]} colunas")
print(f"\nDataset preview:")
print(df.head())
# Out:
# ✅ Bibliotecas importadas!
# ✅ Dataset carregado: 2000 linhas, 8 colunas
#
# Dataset preview:
#    Year       Job_Title  Country Company_Type Experience_Level  Salary_USD  \
# 0  2022  Data Scientist  Germany      Startup            Entry       32058
# 1  2025  Data Scientist      USA      Startup            Entry       45821
# 2  2023    NLP Engineer    India      Startup              Mid       31292
# 3  2025     AI Engineer  Germany      Startup            Entry       46264
# 4  2024     AI Engineer   Canada     Big Tech            Entry       57624
#
#   Remote Top_Skill
# 0    Yes       NLP
# 1    Yes       NLP
# 2    Yes       SQL
# 3     No    Python
# 4     No    Python
